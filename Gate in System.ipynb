# %%
svsim = Aer.get_backend('aer_simulator')
qc.save_unitary()
qobj = assemble(qc)
unitary = svsim.run(qobj).result().get_unitary()
#plot_bloch_multivector(unitary)
array_to_latex(unitary,prefix="\\text{circuit=}\n")

svsim = Aer.get_backend('aer_simulator')
qc.save_statevector()
qobj = assemble(qc)
final_state = svsim.run(qobj).result().get_statevector()
display(array_to_latex(final_state, prefix="\\text{Statevector} = "))

# %%
from qiskit import QuantumCircuit, Aer, assemble
from math import pi, sqrt                                                               
from qiskit.visualization import plot_bloch_multivector, plot_histogram, array_to_latex 
import numpy as np

# %%
# H gate
qc = QuantumCircuit(1)
qc.h(0)
style = {'backgroundcolor': 'lavender'}
qc.draw(output='mpl',style = style)

svsim = Aer.get_backend('aer_simulator')
qc.save_unitary()
qobj = assemble(qc)
unitary = svsim.run(qobj).result().get_unitary()
array_to_latex(unitary,prefix="\\text{circuit=}\n")
# Out:
# $$
# \text{circuit=}
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}}  \\
#  \tfrac{1}{\sqrt{2}} & -\tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %%
svsim = Aer.get_backend('aer_simulator')
qc.save_statevector()
qobj = assemble(qc)
final_state = svsim.run(qobj).result().get_statevector()
display(array_to_latex(final_state, prefix="\\text{Statevector} = "))
# Out:
# $$
# \text{Statevector} =
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %%
svsim = Aer.get_backend('aer_simulator')
qc1.save_unitary()
qobj = assemble(qc1)
unitary = svsim.run(qobj).result().get_unitary()
array_to_latex(unitary,prefix="\\text{circuit=}\n")
plot_bloch_multivector(unitary)
# Out:
# Simulation failed and returned the following error message:
# ERROR:  [Experiment 0] AerSimulator: circuit with instructions {"instructions": {gate, save_statevector, save_unitary}, "gates": {x}} is not compatible with any of the automatic simulation methods
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13028/2537604924.py in <module>
#       2 qc1.save_unitary()
#       3 qobj = assemble(qc1)
# ----> 4 unitary = svsim.run(qobj).result().get_unitary()
#       5 array_to_latex(unitary,prefix="\\text{circuit=}\n")
#       6 plot_bloch_multivector(unitary)
#
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\qiskit\result\result.py in get_unitary(self, experiment, decimals)
#     345         """
#     346         try:
# --> 347             return postprocess.format_unitary(self.data(experiment)["unitary"], decimals=decimals)
#     348         except KeyError as ex:
#     349             raise QiskitError(f'No unitary for experiment "{repr(experiment)}"') from ex
#
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\qiskit\result\result.py in data(self, experiment)
#     196         """
#     197         try:
# --> 198             return self._get_experiment(experiment).data.to_dict()
#     199         except (KeyError, TypeError) as ex:
#     200             raise QiskitError(f'No data for experiment "{repr(experiment)}"') from ex
#
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\qiskit\result\result.py in _get_experiment(self, key)
#     407         result_status = getattr(self, "status", "Result was not successful")
#     408         exp_status = getattr(exp, "status", "Experiment was not successful")
# --> 409         raise QiskitError(result_status, ", ", exp_status)
#
# QiskitError: 'ERROR:  [Experiment 0] AerSimulator: circuit with instructions {"instructions": {gate, save_statevector, save_unitary}, "gates": {x}} is not compatible with any of the automatic simulation methods ,  ERROR: AerSimulator: circuit with instructions {"instructions": {gate, save_statevector, save_unitary}, "gates": {x}} is not compatible with any of the automatic simulation methods'

# %%
qc1=QuantumCircuit(1)
qc1.x(0)
style = {'backgroundcolor': 'lavender'}
qc1.draw(output='mpl',style = style)

# %%
svsim = Aer.get_backend('aer_simulator')
qc1.save_statevector()
qobj = assemble(qc1)
final_state = svsim.run(qobj).result().get_statevector()
display(array_to_latex(final_state, prefix="\\text{Statevector} = "))
plot_bloch_multivector(unitary)
# Out:
# $$
# \text{Statevector} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\qiskit\visualization\bloch.py:68: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
svsim = Aer.get_backend('aer_simulator')
qc1.save_statevector()
qobj = assemble(qc1)
final_state = svsim.run(qobj).result().get_statevector()
display(array_to_latex(final_state, prefix="\\text{Statevector} = "))
plot_bloch_multivector(unitary)
# Out:
# $$
# \text{Statevector} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\qiskit\visualization\bloch.py:68: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
svsim = Aer.get_backend('aer_simulator')
qc2.save_unitary()
qobj = assemble(qc2)
unitary = svsim.run(qobj).result().get_unitary()
array_to_latex(unitary,prefix="\\text{circuit=}\n")

# %%
qc2=QuantumCircuit(2)
qc2.y(0)
style = {'backgroundcolor': 'lavender'}
qc2.draw(output='mpl',style = style)

# %%
svsim = Aer.get_backend('aer_simulator')
qc2.save_statevector()
qobj = assemble(qc2)
final_state = svsim.run(qobj).result().get_statevector()
display(array_to_latex(final_state, prefix="\\text{Statevector} = "))
plot_bloch_multivector(unitary)

# %%
svsim = Aer.get_backend('aer_simulator')
qc3.save_unitary()
qobj = assemble(qc3)
unitary = svsim.run(qobj).result().get_unitary()
array_to_latex(unitary,prefix="\\text{circuit=}\n")

# %%
qc3=QuantumCircuit(2)
qc3.z(0)
style={'backgroundcolor':'lavender'}
qc3.draw(output='mpl',style=style)

# %%
svsim = Aer.get_backend('aer_simulator')
qc3.save_statevector()
qobj = assemble(qc3)
final_state = svsim.run(qobj).result().get_statevector()
display(array_to_latex(final_state, prefix="\\text{Statevector} = "))
plot_bloch_multivector(unitary)
